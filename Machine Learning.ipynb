# %%
matplotlib inline

# %%
#Comments:
#   Placeholder for comments

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
num = 100
a = np.random.rand(num)
b = np.random.rand(num)
color = np.random.rand(num)
area = np.pi * (15 * np.random.rand(num)) ** 2

# %%
plt.scatter(a, b, s=area, c=color, alpha=0.4)
plt.show()

# %%
# %%HTML
# <table style="width:50%">
#   <tr>
#     <th>Row 1</th>
#     <th>Row 2</th>
#     <th>Row 3</th>
#   </tr>
#   <tr>
#     <td>Input 1</td>
#     <td>Input 2</td>
#     <td>Input 3</td>
#   </tr>
#   <tr>
#     <td>Input 4</td>
#     <td>Input 5</td>
#     <td>Input 6</td>
#   </tr>
# </table>
# Out:
# <table style="width:50%">
#   <tr>
#     <th>Row 1</th>
#     <th>Row 2</th>
#     <th>Row 3</th>
#   </tr>
#   <tr>
#     <td>Input 1</td>
#     <td>Input 2</td>
#     <td>Input 3</td>
#   </tr>
#   <tr>
#     <td>Input 4</td>
#     <td>Input 5</td>
#     <td>Input 6</td>
#   </tr>
# </table>

# %%
# %%timeit
square = [n*n for n in range(1000)]
# Out:
# 90.1 µs ± 11.5 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)
